# %% [markdown]
# # ML Model Training NotebookThis notebook trains a predictive velocity model for the ML-Player-Piano project.It takes recorded keypress data (velocity, timing, hammer travel) and learns a model to improve solenoid strike accuracy.
